# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import preprocessing
from geopy.geocoders import Nominatim

# %% [markdown]
# ### load the datasets

# %%
df_location = pd.read_csv("dataset/location.csv")

# %%
df_cases = pd.read_csv("dataset/individual.csv")

# %% [markdown]
# ### info about individul cases dataset

# %%
df_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557364 entries, 0 to 557363
# Data columns (total 10 columns):
# age                       260490 non-null object
# sex                       263630 non-null object
# province                  550796 non-null object
# country                   557340 non-null object
# latitude                  557362 non-null float64
# longitude                 557362 non-null float64
# date_confirmation         556902 non-null object
# additional_information    34395 non-null object
# source                    348173 non-null object
# outcome                   557364 non-null object
# dtypes: float64(2), object(8)
# memory usage: 42.5+ MB

# %%
df_cases.describe()
# Out:
#             latitude      longitude
# count  557362.000000  557362.000000
# mean       18.138385      27.285771
# std        20.455801      67.577194
# min       -54.808030    -159.727596
# 25%        11.042850     -58.473080
# 50%        19.036810      72.834830
# 75%        28.456000      77.209100
# max        70.071800     174.740000

# %%
# out of total 557,364 values 260,490 values are not NULL in age column => 296,874 missing age values

# %% [markdown]
# ### Data cleaning for age column

# %%
age_col = df_cases['age']
age_col = age_col.to_frame()
# age_col = age_col[age_col['age'].notna()]
# age_col.head()

# %%
age_col['format']= age_col['age'].str.extract(r'([0-9][0-9]-[0-9][0-9])')
a = age_col['format'].str.extract(r'([0-9][0-9])')
b = age_col['format'].str.extract(r'(-[0-9][0-9])')
b = b[0].str.extract(r'([0-9][0-9])')
b[0] = pd.to_numeric(b[0])
a[0] = pd.to_numeric(a[0])

new = round((a[0]+b[0])/2)
new = new.to_frame()
# new = new.dropna()
age_col['format'] = new[0]

# %%
age_col.head()
# Out:
#     age  format
# 0   NaN     NaN
# 1  21.0     NaN
# 2  94.0     NaN
# 3   NaN     NaN
# 4   2.0     NaN

# %%
age_col['format2'] = age_col['age'].str.extract(r'([0-9]+)')
# here merge format2 into format and made format = age

age_col.format[age_col.format.isnull()] = age_col.format2
age_col.age = age_col.format
# age_col
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
type(age_col.age)
age_col.age= pd.to_numeric(age_col.age)

# %%
age_col.age.describe()
# Out:
# count    260490.000000
# mean         43.701194
# std          19.922561
# min           0.000000
# 25%          28.000000
# 50%          44.000000
# 75%          57.000000
# max         121.000000
# Name: age, dtype: float64

# %%
total_na_values = len(age_col) - age_col.count()
total_na_values
# Out:
# age        296874
# format     296874
# format2    296874
# dtype: int64

# %% [markdown]
# ### Replace orignal age column with the new formatted age column

# %%
df_cases.age = age_col.age 
df_cases
# Out:
#          age     sex          province country  latitude  longitude  \
# 0        NaN     NaN           Gujarat   India  23.02776   72.60027
# 1       21.0    male         Moyobamba    Peru  -6.03271  -76.97230
# 2       94.0  female              Lima    Peru -12.04318  -77.02824
# 3        NaN     NaN           Gujarat   India  23.02776   72.60027
# 4        2.0  female  Coronel Portillo    Peru  -8.40921  -74.55572
# ...      ...     ...               ...     ...       ...        ...
# 557359  56.0    male            Callao    Peru -12.04175  -77.09082
# 557360   NaN     NaN       Maharashtra   India  18.94017   72.83483
# 557361   NaN     NaN       Maharashtra   India  19.03681   73.01582
# 557362  25.0  female        Tamil Nadu   India  13.08362   80.28252
# 557363   NaN     NaN         Rajasthan   India  26.26691   73.03052
#
#        date_confirmation additional_information  \
# 0             15.04.2020                    NaN
# 1             09.05.2020                    NaN
# 2             15.04.2020                    NaN
# 3             22.05.2020                    NaN
# 4             30.04.2020                    NaN
# ...                  ...                    ...
# 557359        15.04.2020                    NaN
# 557360        29.05.2020                    NaN
# 557361        19.05.2020                    NaN
# 557362        31.05.2020                    NaN
# 557363        08.05.2020                    NaN
#
#                                                    source          outcome
# 0       https://gujcovid19.gujarat.gov.in/uploads/pres...     hospitalized
# 1                                                     NaN  nonhospitalized
# 2                                                     NaN  nonhospitalized
# 3       https://www.deshgujarat.com/2020/05/22/gujarat...     hospitalized
# 4                                                     NaN  nonhospitalized
# ...                                                   ...              ...
# 557359                                                NaN  nonhospitalized
# 557360  https://arogya.maharashtra.gov.in/pdf/ncovidep...        recovered
# 557361                                                NaN        recovered
# 557362  https://stopcorona.tn.gov.in/wp-content/upload...     hospitalized
# 557363  https://twitter.com/ANI/status/125878720879583...        recovered
#
# [557364 rows x 10 columns]

# %% [markdown]
# ### Explored Decision Tree Classifier to impute misssing age and sex values

# %%
df = df_cases
# df

# %%
df = df.drop(['additional_information'], axis=1)

# %%
df = df.drop(['source'], axis =1)

# %%
df
# Out:
#          age     sex          province country  latitude  longitude  \
# 0        NaN     NaN           Gujarat   India  23.02776   72.60027
# 1       21.0    male         Moyobamba    Peru  -6.03271  -76.97230
# 2       94.0  female              Lima    Peru -12.04318  -77.02824
# 3        NaN     NaN           Gujarat   India  23.02776   72.60027
# 4        2.0  female  Coronel Portillo    Peru  -8.40921  -74.55572
# ...      ...     ...               ...     ...       ...        ...
# 557359  56.0    male            Callao    Peru -12.04175  -77.09082
# 557360   NaN     NaN       Maharashtra   India  18.94017   72.83483
# 557361   NaN     NaN       Maharashtra   India  19.03681   73.01582
# 557362  25.0  female        Tamil Nadu   India  13.08362   80.28252
# 557363   NaN     NaN         Rajasthan   India  26.26691   73.03052
#
#        date_confirmation          outcome
# 0             15.04.2020     hospitalized
# 1             09.05.2020  nonhospitalized
# 2             15.04.2020  nonhospitalized
# 3             22.05.2020     hospitalized
# 4             30.04.2020  nonhospitalized
# ...                  ...              ...
# 557359        15.04.2020  nonhospitalized
# 557360        29.05.2020        recovered
# 557361        19.05.2020        recovered
# 557362        31.05.2020     hospitalized
# 557363        08.05.2020        recovered
#
# [557364 rows x 8 columns]

# %%
df_nan = df[df.isnull().any(axis=1)] #dataset age and sex to be predicted 
featutre_cols = ['latitide', 'longitude']

# %%
df_nan
# X_ = df_nan[feature_cols]
# X_ = X_.fillna(0)
# X_
# Out:
#         age  sex     province country  latitude  longitude date_confirmation  \
# 0       NaN  NaN      Gujarat   India  23.02776  72.600270        15.04.2020
# 3       NaN  NaN      Gujarat   India  23.02776  72.600270        22.05.2020
# 6       NaN  NaN        Delhi   India  28.61474  77.209100        01.06.2020
# 7       NaN  NaN  Maharashtra   India  18.94017  72.834830        31.05.2020
# 9       NaN  NaN  West Bengal   India  23.79776  87.986406        11.04.2020
# ...     ...  ...          ...     ...       ...        ...               ...
# 557357  NaN  NaN       Odisha   India  20.85000  86.333330        01.06.2020
# 557358  NaN  NaN      Gujarat   India  22.31389  74.013930        25.04.2020
# 557360  NaN  NaN  Maharashtra   India  18.94017  72.834830        29.05.2020
# 557361  NaN  NaN  Maharashtra   India  19.03681  73.015820        19.05.2020
# 557363  NaN  NaN    Rajasthan   India  26.26691  73.030520        08.05.2020
#
#              outcome
# 0       hospitalized
# 3       hospitalized
# 6       hospitalized
# 7       hospitalized
# 9       hospitalized
# ...              ...
# 557357     recovered
# 557358  hospitalized
# 557360     recovered
# 557361     recovered
# 557363     recovered
#
# [304077 rows x 8 columns]

# %%
df = df.dropna()
# df

# %%
le = preprocessing.LabelEncoder()
data = df.apply(le.fit_transform)
feature_cols = ['latitude', 'longitude']
# data

# %%
X = data[feature_cols] # Features
y = data.sex #target variable
X.head()
# Out:
#    latitude  longitude
# 1      1261        753
# 2       814        733
# 4      1069       1299
# 5       580       1039
# 8      4737       2681

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
# df_nan

# %%
clf = tree.DecisionTreeClassifier()

# %%
clf = clf.fit(X_train,y_train)

# %%
# data_ = df_nan.apply(le.fit_transform)
# data_
y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5522655191019517

# %%
# Y_ = clf.predict(X_)
# Y_

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %% [markdown]
# ### Another approach to impute values

# %%
df_cases
# Out:
#          age     sex          province country  latitude  longitude  \
# 0        NaN     NaN           Gujarat   India  23.02776   72.60027
# 1       21.0    male         Moyobamba    Peru  -6.03271  -76.97230
# 2       94.0  female              Lima    Peru -12.04318  -77.02824
# 3        NaN     NaN           Gujarat   India  23.02776   72.60027
# 4        2.0  female  Coronel Portillo    Peru  -8.40921  -74.55572
# ...      ...     ...               ...     ...       ...        ...
# 557359  56.0    male            Callao    Peru -12.04175  -77.09082
# 557360   NaN     NaN       Maharashtra   India  18.94017   72.83483
# 557361   NaN     NaN       Maharashtra   India  19.03681   73.01582
# 557362  25.0  female        Tamil Nadu   India  13.08362   80.28252
# 557363   NaN     NaN         Rajasthan   India  26.26691   73.03052
#
#        date_confirmation additional_information  \
# 0             15.04.2020                    NaN
# 1             09.05.2020                    NaN
# 2             15.04.2020                    NaN
# 3             22.05.2020                    NaN
# 4             30.04.2020                    NaN
# ...                  ...                    ...
# 557359        15.04.2020                    NaN
# 557360        29.05.2020                    NaN
# 557361        19.05.2020                    NaN
# 557362        31.05.2020                    NaN
# 557363        08.05.2020                    NaN
#
#                                                    source          outcome
# 0       https://gujcovid19.gujarat.gov.in/uploads/pres...     hospitalized
# 1                                                     NaN  nonhospitalized
# 2                                                     NaN  nonhospitalized
# 3       https://www.deshgujarat.com/2020/05/22/gujarat...     hospitalized
# 4                                                     NaN  nonhospitalized
# ...                                                   ...              ...
# 557359                                                NaN  nonhospitalized
# 557360  https://arogya.maharashtra.gov.in/pdf/ncovidep...        recovered
# 557361                                                NaN        recovered
# 557362  https://stopcorona.tn.gov.in/wp-content/upload...     hospitalized
# 557363  https://twitter.com/ANI/status/125878720879583...        recovered
#
# [557364 rows x 10 columns]

# %%
df_cases = df_cases.drop(['additional_information', 'source'], axis=1)

# %%
df_cases.head()
# Out:
#     age     sex          province country  latitude  longitude  \
# 0   NaN     NaN           Gujarat   India  23.02776   72.60027
# 1  21.0    male         Moyobamba    Peru  -6.03271  -76.97230
# 2  94.0  female              Lima    Peru -12.04318  -77.02824
# 3   NaN     NaN           Gujarat   India  23.02776   72.60027
# 4   2.0  female  Coronel Portillo    Peru  -8.40921  -74.55572
#
#   date_confirmation          outcome
# 0        15.04.2020     hospitalized
# 1        09.05.2020  nonhospitalized
# 2        15.04.2020  nonhospitalized
# 3        22.05.2020     hospitalized
# 4        30.04.2020  nonhospitalized

# %%
df_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557364 entries, 0 to 557363
# Data columns (total 8 columns):
# age                  260490 non-null float64
# sex                  263630 non-null object
# province             550796 non-null object
# country              557340 non-null object
# latitude             557362 non-null float64
# longitude            557362 non-null float64
# date_confirmation    556902 non-null object
# outcome              557364 non-null object
# dtypes: float64(3), object(5)
# memory usage: 34.0+ MB

# %% [markdown]
# ### Age imputed with existing population proportion

# %%
age_col['category_children'] = age_col.age < 15 
age_col['category_young_adults'] = age_col.age < 30
age_col['adults_below_50'] = age_col.age < 50
age_col['elderly'] = age_col.age > 50

# %%
children = age_col.age[age_col.age < 15].count()
children # 5.6% --> put 5.6% values as 8
# Out:
# 14705

# %%
young_adults = age_col.age[age_col.age <30].count()
young_adults = young_adults - children
young_adults # 22% --> 22% values as 23
# Out:
# 57526

# %%
adults_below_50 = age_col.age[age_col.age < 50].count()
adults_below_50 = adults_below_50 - young_adults - children
adults_below_50 # 37.5% --> 37.5% values as 40
# Out:
# 97790

# %%
elderly_below_80 = age_col.age[age_col.age < 80].count()
elderly_below_80 = elderly_below_80 - adults_below_50 - young_adults - children
elderly_below_80 # 28.9% --> 29% values as 67
# Out:
# 75375

# %%
very_elderly = age_col.age[age_col.age >= 80].count()
very_elderly # 5.7% --> values as 90
# Out:
# 15094

# %%
# age_col

# %%
# age_col = age_col.drop(['format', 'format2', 'category', 'category_children', 'category_young_adults', 'adults_below_50', 'elderly'], axis=1)
# age_col

# %%
# 296,874 values to be imputed
# 16,625 - children
# 65,321 - young_adults
# 112,014 - adults < 50
# 86,093 - adults > 50 < 80
# 16,821 - elderly

# %%
new_age = age_col.dropna()
# new_age

# %%
df_with_nan = age_col[age_col.isnull().any(axis=1)] # all data rows with NaN 
df_with_nan.head()
age_col = age_col.drop(['format', 'format2', 'category_children', 'category_young_adults', 'adults_below_50', 'elderly'], axis=1)
age_col.head()
# Out:
#     age
# 0   NaN
# 1  21.0
# 2  94.0
# 3   NaN
# 4   2.0

# %% [markdown]
# ### Imputes age

# %%
count = 0
for index, row in age_col.iterrows():
        if (np.isnan(row.age)):
            count += 1
            if (count <= 16625):
                row['age'] = 8
            elif (count <= 81946):
                row['age'] = 23
            elif (count <= 193960):
                row['age'] = 40
            elif (count <= 280053):
                row['age'] = 67
            else:
                row['age'] = 90
            
# count 8 23 40 67 90
age_col
# Out:
#          age
# 0        8.0
# 1       21.0
# 2       94.0
# 3        8.0
# 4        2.0
# ...      ...
# 557359  56.0
# 557360  90.0
# 557361  90.0
# 557362  25.0
# 557363  90.0
#
# [557364 rows x 1 columns]

# %%
# 16,625 - children
# 65,321 - young_adults
# 112,014 - adults < 50
# 86,093 - adults > 50 < 80
# 16,821 - elderly 
df_cases.age = age_col.age
df_cases
# Out:
#          age     sex          province country  latitude  longitude  \
# 0        8.0     NaN           Gujarat   India  23.02776   72.60027
# 1       21.0    male         Moyobamba    Peru  -6.03271  -76.97230
# 2       94.0  female              Lima    Peru -12.04318  -77.02824
# 3        8.0     NaN           Gujarat   India  23.02776   72.60027
# 4        2.0  female  Coronel Portillo    Peru  -8.40921  -74.55572
# ...      ...     ...               ...     ...       ...        ...
# 557359  56.0    male            Callao    Peru -12.04175  -77.09082
# 557360  90.0     NaN       Maharashtra   India  18.94017   72.83483
# 557361  90.0     NaN       Maharashtra   India  19.03681   73.01582
# 557362  25.0  female        Tamil Nadu   India  13.08362   80.28252
# 557363  90.0     NaN         Rajasthan   India  26.26691   73.03052
#
#        date_confirmation          outcome
# 0             15.04.2020     hospitalized
# 1             09.05.2020  nonhospitalized
# 2             15.04.2020  nonhospitalized
# 3             22.05.2020     hospitalized
# 4             30.04.2020  nonhospitalized
# ...                  ...              ...
# 557359        15.04.2020  nonhospitalized
# 557360        29.05.2020        recovered
# 557361        19.05.2020        recovered
# 557362        31.05.2020     hospitalized
# 557363        08.05.2020        recovered
#
# [557364 rows x 8 columns]

# %% [markdown]
# ### Imputing sex column

# %%
df_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557364 entries, 0 to 557363
# Data columns (total 8 columns):
# age                  557364 non-null float64
# sex                  263630 non-null object
# province             550796 non-null object
# country              557340 non-null object
# latitude             557362 non-null float64
# longitude            557362 non-null float64
# date_confirmation    556902 non-null object
# outcome              557364 non-null object
# dtypes: float64(3), object(5)
# memory usage: 34.0+ MB

# %%
sex_col = df_cases['sex']
type(sex_col)
# Out:
# pandas.core.series.Series

# %%
sex_col = sex_col.to_frame()

# %%
sex_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557364 entries, 0 to 557363
# Data columns (total 1 columns):
# sex    263630 non-null object
# dtypes: object(1)
# memory usage: 4.3+ MB

# %%
sex_col
# Out:
#       sex
# 0     NaN
# 1    male
# 2  female
# 3     NaN
# 4  female

# %%
num_male = sex_col.sex[sex_col.sex == 'male'].count()
num_male
# Out:
# 145583

# %%
num_female = sex_col.sex[sex_col.sex == 'female'].count()
num_female
# Out:
# 118047

# %%
145583/263630 # 55% males and 45% females ---> 161,553 (males) and 132,181 (females)
# Out:
# 0.5522247088722831

# %%
# total nan values in sex field = 293,734
print(sex_col.sex[0])
# Out:
# nan

# %%
count = 0
for index, row in sex_col.iterrows():
    if (pd.isnull(row['sex'])):
        count += 1
        if (count <= 161553):
            row['sex'] = 'male'
        else:
            row['sex'] = 'female'
sex_col
# Out:
#            sex
# 0         male
# 1         male
# 2       female
# 3         male
# 4       female
# ...        ...
# 557359    male
# 557360  female
# 557361  female
# 557362  female
# 557363  female
#
# [557364 rows x 1 columns]

# %%
sex_col.describe()
# count
# Out:
#            sex
# count   557364
# unique       2
# top       male
# freq    307136

# %%
num_female = sex_col.sex[sex_col.sex == 'female'].count()
num_female
# Out:
# 250228

# %%
num_male = sex_col.sex[sex_col.sex == 'male'].count()

# %%
num_male
# Out:
# 307136

# %%
sex_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557364 entries, 0 to 557363
# Data columns (total 1 columns):
# sex    557364 non-null object
# dtypes: object(1)
# memory usage: 4.3+ MB

# %%
df_cases.sex = sex_col.sex
df_cases
# Out:
#          age     sex          province country  latitude  longitude  \
# 0        8.0    male           Gujarat   India  23.02776   72.60027
# 1       21.0    male         Moyobamba    Peru  -6.03271  -76.97230
# 2       94.0  female              Lima    Peru -12.04318  -77.02824
# 3        8.0    male           Gujarat   India  23.02776   72.60027
# 4        2.0  female  Coronel Portillo    Peru  -8.40921  -74.55572
# ...      ...     ...               ...     ...       ...        ...
# 557359  56.0    male            Callao    Peru -12.04175  -77.09082
# 557360  90.0  female       Maharashtra   India  18.94017   72.83483
# 557361  90.0  female       Maharashtra   India  19.03681   73.01582
# 557362  25.0  female        Tamil Nadu   India  13.08362   80.28252
# 557363  90.0  female         Rajasthan   India  26.26691   73.03052
#
#        date_confirmation          outcome
# 0             15.04.2020     hospitalized
# 1             09.05.2020  nonhospitalized
# 2             15.04.2020  nonhospitalized
# 3             22.05.2020     hospitalized
# 4             30.04.2020  nonhospitalized
# ...                  ...              ...
# 557359        15.04.2020  nonhospitalized
# 557360        29.05.2020        recovered
# 557361        19.05.2020        recovered
# 557362        31.05.2020     hospitalized
# 557363        08.05.2020        recovered
#
# [557364 rows x 8 columns]

# %%
df_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557364 entries, 0 to 557363
# Data columns (total 8 columns):
# age                  557364 non-null float64
# sex                  557364 non-null object
# province             550796 non-null object
# country              557340 non-null object
# latitude             557362 non-null float64
# longitude            557362 non-null float64
# date_confirmation    556902 non-null object
# outcome              557364 non-null object
# dtypes: float64(3), object(5)
# memory usage: 34.0+ MB

# %%
province_column = df_cases['province']
province_column
# Out:
# 0                  Gujarat
# 1                Moyobamba
# 2                     Lima
# 3                  Gujarat
# 4         Coronel Portillo
#                 ...
# 557359              Callao
# 557360         Maharashtra
# 557361         Maharashtra
# 557362          Tamil Nadu
# 557363           Rajasthan
# Name: province, Length: 557364, dtype: object

# %%
province_column['country'] = df_cases['country']
# Out:
#                 province country
# 0                Gujarat   India
# 1              Moyobamba    Peru
# 2                   Lima    Peru
# 3                Gujarat   India
# 4       Coronel Portillo    Peru
# ...                  ...     ...
# 557359            Callao    Peru
# 557360       Maharashtra   India
# 557361       Maharashtra   India
# 557362        Tamil Nadu   India
# 557363         Rajasthan   India
#
# [557364 rows x 2 columns]

# %%
province_column['latitude'] = df_cases['latitude']
province_column
# Out:
#                 province country  latitude
# 0                Gujarat   India  23.02776
# 1              Moyobamba    Peru  -6.03271
# 2                   Lima    Peru -12.04318
# 3                Gujarat   India  23.02776
# 4       Coronel Portillo    Peru  -8.40921
# ...                  ...     ...       ...
# 557359            Callao    Peru -12.04175
# 557360       Maharashtra   India  18.94017
# 557361       Maharashtra   India  19.03681
# 557362        Tamil Nadu   India  13.08362
# 557363         Rajasthan   India  26.26691
#
# [557364 rows x 3 columns]

# %%
province_column['longitude'] = df_cases['longitude']
province_column
# Out:
#                 province country  latitude  longitude
# 0                Gujarat   India  23.02776   72.60027
# 1              Moyobamba    Peru  -6.03271  -76.97230
# 2                   Lima    Peru -12.04318  -77.02824
# 3                Gujarat   India  23.02776   72.60027
# 4       Coronel Portillo    Peru  -8.40921  -74.55572
# ...                  ...     ...       ...        ...
# 557359            Callao    Peru -12.04175  -77.09082
# 557360       Maharashtra   India  18.94017   72.83483
# 557361       Maharashtra   India  19.03681   73.01582
# 557362        Tamil Nadu   India  13.08362   80.28252
# 557363         Rajasthan   India  26.26691   73.03052
#
# [557364 rows x 4 columns]

# %%
df_nan_province = province_column[province_column.province.isnull()]

# %%
df_nan_province
# Out:
#        province      country   latitude   longitude
# 13          NaN       Turkey  39.102050   35.173550
# 64          NaN        Sudan  15.551770   32.532410
# 105         NaN        Ghana   7.977254   -1.210600
# 281         NaN  Philippines  11.816130  122.848400
# 321         NaN  Philippines  11.816130  122.848400
# ...         ...          ...        ...         ...
# 556845      NaN  Philippines  11.816130  122.848400
# 556963      NaN      Belgium  50.647090    4.658573
# 557170      NaN      Belgium  50.647090    4.658573
# 557209      NaN  Philippines  11.816130  122.848400
# 557217      NaN  Philippines  11.816130  122.848400
#
# [6568 rows x 4 columns]

# %%
geolocator = Nominatim(user_agent="myGeocoder")

# %%
temp = province_column[province_column.latitude.isnull()]
temp
# Out:
#        province country  latitude  longitude
# 340945      NaN     NaN       NaN        NaN
# 365285      NaN     NaN       NaN        NaN

# %%
df_cases.iloc[340945]
df_cases.loc[365285]
# Out:
# age                               67
# sex                           female
# province                         NaN
# country                          NaN
# latitude                         NaN
# longitude                        NaN
# date_confirmation                NaN
# outcome              nonhospitalized
# Name: 365285, dtype: object

# %%
df_cases = df_cases.drop(340945, axis =0 )

# %%
df_cases = df_cases.drop(365285)

# %%
df_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 557362 entries, 0 to 557363
# Data columns (total 8 columns):
# age                  557362 non-null float64
# sex                  557362 non-null object
# province             550796 non-null object
# country              557340 non-null object
# latitude             557362 non-null float64
# longitude            557362 non-null float64
# date_confirmation    556902 non-null object
# outcome              557362 non-null object
# dtypes: float64(3), object(5)
# memory usage: 38.3+ MB

# %%
df_cases.to_csv("individual_dataset.csv")

# %%
df = pd.read_csv("individual_dataset.csv")
df = df.drop(columns=['Unnamed: 0'])
df
# Out:
#          age     sex          province country  latitude  longitude  \
# 0        8.0    male           Gujarat   India  23.02776   72.60027
# 1       21.0    male         Moyobamba    Peru  -6.03271  -76.97230
# 2       94.0  female              Lima    Peru -12.04318  -77.02824
# 3        8.0    male           Gujarat   India  23.02776   72.60027
# 4        2.0  female  Coronel Portillo    Peru  -8.40921  -74.55572
# ...      ...     ...               ...     ...       ...        ...
# 557357  56.0    male            Callao    Peru -12.04175  -77.09082
# 557358  90.0  female       Maharashtra   India  18.94017   72.83483
# 557359  90.0  female       Maharashtra   India  19.03681   73.01582
# 557360  25.0  female        Tamil Nadu   India  13.08362   80.28252
# 557361  90.0  female         Rajasthan   India  26.26691   73.03052
#
#        date_confirmation          outcome
# 0             15.04.2020     hospitalized
# 1             09.05.2020  nonhospitalized
# 2             15.04.2020  nonhospitalized
# 3             22.05.2020     hospitalized
# 4             30.04.2020  nonhospitalized
# ...                  ...              ...
# 557357        15.04.2020  nonhospitalized
# 557358        29.05.2020        recovered
# 557359        19.05.2020        recovered
# 557360        31.05.2020     hospitalized
# 557361        08.05.2020        recovered
#
# [557362 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557362 entries, 0 to 557361
# Data columns (total 8 columns):
# age                  557362 non-null float64
# sex                  557362 non-null object
# province             550796 non-null object
# country              557340 non-null object
# latitude             557362 non-null float64
# longitude            557362 non-null float64
# date_confirmation    556902 non-null object
# outcome              557362 non-null object
# dtypes: float64(3), object(5)
# memory usage: 34.0+ MB
