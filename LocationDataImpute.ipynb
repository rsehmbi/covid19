# %%
import pandas as pd
import numpy as np

# %%
ProcessedLocations = pd.read_csv("ImputedProvince.csv")

# %%
ProcessedLocations.head()
ProcessedLocations.set_index('Unnamed: 0')
ProcessedLocations.columns
# Out:
# Index(['Unnamed: 0', 'Province_State', 'Country_Region', 'Last_Update', 'Lat',
#        'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Combined_Key',
#        'Incidence_Rate', 'Case-Fatality_Ratio', 'geom'],
#       dtype='object')

# %%
ProcessedLocations = ProcessedLocations.dropna(how='any',axis=0)

# %%
ProcessedLocations['Province'] = ProcessedLocations["Province_State"]
ProcessedLocations.drop('Unnamed: 0', axis=1, inplace=True)
ProcessedLocations
# Out:
#                 Province_State        Country_Region          Last_Update  \
# 0           Мурманская область           Afghanistan  2020-09-20 04:22:56
# 2                        Ituri               Algeria  2020-09-20 04:22:56
# 3    Jubbada Dhexe جوبا الوسطى               Andorra  2020-09-20 04:22:56
# 4                      العصابة                Angola  2020-09-20 04:22:56
# 7                       Адыгея               Armenia  2020-09-20 04:22:56
# ..                         ...                   ...                  ...
# 155     El Bayadh ⵍⴱⴻⵢⴻⴹ البيض                Uganda  2020-09-20 04:22:56
# 156      województwo podlaskie  United Arab Emirates  2020-09-20 04:22:56
# 158      Архангельская область            Uzbekistan  2020-09-20 04:22:56
# 162     North-Western Province        Western Sahara  2020-09-20 04:22:56
# 163           Niederösterreich                 Yemen  2020-09-20 04:22:56
#
#            Lat      Long_  Confirmed  Deaths  Recovered   Active  \
# 0    33.939110  67.709953      38919    1437      32576   4906.0
# 2    28.033900   1.659600      49623    1665      34923  13035.0
# 3    42.506300   1.521800       1564      53       1164    347.0
# 4   -11.202700  17.873900       3901     147       1445   2309.0
# 7    40.069100  45.038200      47154     928      42551   3675.0
# ..         ...        ...        ...     ...        ...      ...
# 155   1.373333  32.290275       6017      63       2581   3373.0
# 156  23.424076  53.847818      84242     404      73512  10326.0
# 158  41.377491  64.585262      50992     427      47271   3294.0
# 162  24.215500 -12.885800         10       1          8      1.0
# 163  15.552727  48.516388       2026     585       1221    220.0
#
#              Combined_Key  Incidence_Rate  Case-Fatality_Ratio  \
# 0             Afghanistan       99.976005             3.692284
# 2                 Algeria      113.162645             3.355299
# 3                 Andorra     2024.202420             3.388747
# 4                  Angola       11.869312             3.768265
# 7                 Armenia     1591.301936             1.968020
# ..                    ...             ...                  ...
# 155                Uganda       13.154500             1.047033
# 156  United Arab Emirates      851.755237             0.479571
# 158            Uzbekistan      152.355006             0.837386
# 162        Western Sahara        1.674116            10.000000
# 163                 Yemen        6.792738            28.874630
#
#                      geom                   Province
# 0     67.709953, 33.93911         Мурманская область
# 2         1.6596, 28.0339                      Ituri
# 3         1.5218, 42.5063  Jubbada Dhexe جوبا الوسطى
# 4       17.8739, -11.2027                    العصابة
# 7        45.0382, 40.0691                     Адыгея
# ..                    ...                        ...
# 155   32.290275, 1.373333     El Bayadh ⵍⴱⴻⵢⴻⴹ البيض
# 156  53.847818, 23.424076      województwo podlaskie
# 158  64.585262, 41.377491      Архангельская область
# 162     -12.8858, 24.2155     North-Western Province
# 163  48.516388, 15.552727           Niederösterreich
#
# [65 rows x 14 columns]

# %%
Index_List = ProcessedLocations['Unnamed: 0'].values.tolist()
Values_List = ProcessedLocations['Province_State'].tolist()
Values_List
# Out:
# ['Мурманская область',
#  'Ituri',
#  'Jubbada Dhexe جوبا الوسطى',
#  'العصابة',
#  'Адыгея',
#  'محافظة شبوة',
#  'Ростовская область',
#  'Рівненська область',
#  'استان فارس',
#  'منطقة القصيم',
#  'Ogooué-Lolo',
#  'Béni Abbès ⴰⵢⵜ ⴰⴱⴱⴰⵙ بني عباس',
#  'Khomas Region',
#  'Kebbi',
#  'In Guezzam ⵄⵉⵏ ⴳⴻⵣⵣⴰⵎ عين قزام',
#  'Gao',
#  'Tombouctou',
#  'محافظة مأرب',
#  'محافظة حضرموت',
#  'Lazio',
#  'مطروح',
#  'Atakora',
#  'Sardegna',
#  'بلوچستان',
#  'Huíla',
#  'Карачаево-Черкесия',
#  'منطقة مكة المكرمة',
#  'አፋር ክልል / Afar',
#  'Могилёвская область',
#  'Ненецкий автономный округ',
#  'منطقة مكة المكرمة',
#  'Одеська область',
#  'ولاية شمال دارفور',
#  'سناج Sanaag',
#  'أبو ظبي',
#  'Kwilu',
#  'كسلا',
#  'Lunda Sul',
#  'المنطقة الشرقية',
#  'ሶማሌ ክልል / Somali',
#  'Katavi',
#  'Mandoul ماندول',
#  'Plateau',
#  'منطقة مكة المكرمة',
#  'Klaipėdos apskritis',
#  'المنطقة الشرقية',
#  'Волинська область',
#  'Béni Abbès ⴰⵢⵜ ⴰⴱⴱⴰⵙ بني عباس',
#  'محافظة لحج',
#  'Volta Region',
#  'Huíla',
#  'Scotland',
#  'المنطقة الشرقية',
#  'محافظة شبوة',
#  'Auvergne-Rhône-Alpes',
#  'Ouargla ⵡⴰⵔⴳⵍⴰ ورقلة',
#  'الجبل الغربي',
#  'توجدير Togdheer',
#  'ولاية النيل الأزرق',
#  'محافظة حمص',
#  'El Bayadh ⵍⴱⴻⵢⴻⴹ البيض',
#  'województwo podlaskie',
#  'Архангельская область',
#  'North-Western Province',
#  'Niederösterreich']

# %%
DataFrameNan = pd.read_csv("dataset/processed_location_Sep20th2020.csv")

# %%
DataFrameNan = DataFrameNan[DataFrameNan['Province_State'].notna()]
DataFrameNan
# Out:
#                     Province_State  Country_Region          Last_Update  \
# 8     Australian Capital Territory       Australia  2020-09-20 04:22:56
# 9                  New South Wales       Australia  2020-09-20 04:22:56
# 10              Northern Territory       Australia  2020-09-20 04:22:56
# 11                      Queensland       Australia  2020-09-20 04:22:56
# 12                 South Australia       Australia  2020-09-20 04:22:56
# ...                            ...             ...                  ...
# 3940              Northern Ireland  United Kingdom  2020-09-20 04:22:56
# 3941                      Scotland  United Kingdom  2020-09-20 04:22:56
# 3942      Turks and Caicos Islands  United Kingdom  2020-09-20 04:22:56
# 3943                       Unknown  United Kingdom  2020-09-20 04:22:56
# 3944                         Wales  United Kingdom  2020-09-20 04:22:56
#
#           Lat     Long_  Confirmed  Deaths  Recovered   Active  \
# 8    -35.4735  149.0124        113       3        110      0.0
# 9    -33.8688  151.2093       4200      53       2994   1153.0
# 10   -12.4634  130.8456         33       0         31      2.0
# 11   -27.4698  153.0251       1152       6       1123     23.0
# 12   -34.9285  138.6007        466       4        462      0.0
# ...       ...       ...        ...     ...        ...      ...
# 3940  54.7877   -6.4923       9165     575          0   8590.0
# 3941  56.4907   -4.2026      24126    2505          0  21621.0
# 3942  21.6940  -71.7979        668       5        572     91.0
# 3943      NaN       NaN          0       0          0      0.0
# 3944  52.1307   -3.7837      20445    1603          0  18842.0
#
#                                   Combined_Key  Incidence_Rate  \
# 8      Australian Capital Territory, Australia       26.395702
# 9                   New South Wales, Australia       51.736881
# 10               Northern Territory, Australia       13.436482
# 11                       Queensland, Australia       22.519793
# 12                  South Australia, Australia       26.530031
# ...                                        ...             ...
# 3940          Northern Ireland, United Kingdom      487.085459
# 3941                  Scotland, United Kingdom      441.601230
# 3942  Turks and Caicos Islands, United Kingdom     1725.295728
# 3943                   Unknown, United Kingdom             NaN
# 3944                     Wales, United Kingdom      651.405085
#
#       Case-Fatality_Ratio
# 8                2.654867
# 9                1.261905
# 10               0.000000
# 11               0.520833
# 12               0.858369
# ...                   ...
# 3940             6.273868
# 3941            10.382989
# 3942             0.748503
# 3943                  NaN
# 3944             7.840548
#
# [3786 rows x 12 columns]

# %%
pd.concat([df1, df2])
new_column = pd.Series(Values_List,name='Province_State', index=Index_List)
new_column
# Out:
# 0              Мурманская область
# 2                           Ituri
# 3       Jubbada Dhexe جوبا الوسطى
# 4                         العصابة
# 7                          Адыгея
#                   ...
# 3901       El Bayadh ⵍⴱⴻⵢⴻⴹ البيض
# 3929        województwo podlaskie
# 3946        Архангельская область
# 3950       North-Western Province
# 3951             Niederösterreich
# Name: Province_State, Length: 65, dtype: object

# %%
DataFrameNan = DataFrameNan.update(new_column)

# %%
DataFrameNan.loc[new_column.index] = new_column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-12f15c4d2166> in <module>
# ----> 1 DataFrameNan.loc[new_column.index] = new_column
#
# AttributeError: 'NoneType' object has no attribute 'loc'

# %%
DataFrameNan.dropna(how="any", inplace=True)
DataFrameNan = DataFrameNan.fillna("", inplace=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-167bb2613909> in <module>
# ----> 1 DataFrameNan.dropna(how="any", inplace=True)
#       2 DataFrameNan = DataFrameNan.fillna("", inplace=False)
#
# AttributeError: 'NoneType' object has no attribute 'dropna'
